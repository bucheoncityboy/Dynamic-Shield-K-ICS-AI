# %%
# !python kics_real.py
# Out:
# === Phase 1: Risk Paradox Proof ===
# [-] Optimal Hedge Ratio: 32.0%
# [-] SCR at 100% Hedge: 36,090,165 KRW
# [-] SCR at Sweet Spot: 33,470,285 KRW
# [-] Capital Saved: 2,619,880 KRW
# Figure(1000x500)

# %%
# !python kics_surrogate.py
# Out:
# === Phase 2-2: Training AI Surrogate Model ===
# [-] Training MLP...
#
# [-] Validating Scalability...
# [-] Scalability Test (Asset: 10B KRW): MAPE = 0.0385%
# [SUCCESS] AI Brain is Robust & Scalable!
# Figure(800x600)

# %%
# !python regime.py
# Out:
# === Phase 2-3: Regime Detection ===
# [-] Generating Synthetic Data...
# [-] Training HMM on 981 data points...
# [-] Mapping Hidden States...
#     State 0: VIX Mean = 14.88 -> Normal
#     State 1: VIX Mean = 15.21 -> Transition
#     State 2: VIX Mean = 26.45 -> Panic
#
# [-] Verifying outputs...
#            VIX  FX_MA_Div  Regime_True Regime_Pred
# 990  13.680795   0.113364            0  Transition
# 991  11.540204   0.061516            0      Normal
# 992  11.595573  -0.002517            0  Transition
# 993  13.774611   0.061211            0      Normal
# 994  12.970130  -0.014368            0  Transition
# 995  14.236952  -0.073237            0      Normal
# 996  17.738510  -0.172855            0  Transition
# 997  14.241191  -0.144329            0      Normal
# 998  16.762367  -0.170570            0  Transition
# 999  22.245701  -0.079151            1      Normal
# Figure(1500x800)

# %%
# !python system.py
# Out:
# === Initializing Dynamic Shield v3.0 System ===
# [-] Training AI Surrogate Model (sklearn MLP)...
# [-] Validation MAPE: 0.0410%
# [SUCCESS] AI Brain is Robust!
# [-] Initializing Regime Detector...
# [-] Training HMM on 981 data points...
# [-] Mapping Hidden States...
#     State 0: VIX Mean = 14.88 -> Normal
#     State 1: VIX Mean = 15.21 -> Transition
#     State 2: VIX Mean = 26.45 -> Panic
#
# === Starting Real-time Simulation (200 Ticks) ===
# [-] Mode: Walk-Forward Validation (Future Data)
#
# === Simulation Results ===
# Total Ticks: 200
#
# [1] Regime Coverage:
# Regime
# Normal        137
# Transition     32
# Panic          31
# Name: count, dtype: int64
#
# [2] AI Accuracy:
# [-] Mean Absolute Error: 0.000194
# [-] Max Error: 0.000433
# [PASS] AI is Highly Accurate & Robust.
#
# [3] Safety Layer Check:
# [-] Avg Hedge Ratio during Panic: 0.93
# [PASS] System successfully increased hedge ratio during Panic.
# Figure(1200x1000)

# %%
# !python ppo_trainer.py
# Out:
# ============================================================
# Phase 4: RL Training with PPO
# ============================================================
# Using cpu device
#
# [Model] PPO initialized
# [Environment] KICS Gym Environment
# [Constraint] K-ICS < 100% -> -1000 penalty
#
# [Training Started]
#   Total Timesteps: 50000
#   Learning Rate: 0.0003
# ------------------------------------------------------------
# Logging to ./tensorboard_logs/PPO_3
#
#    0% -------------------------------- 0/50,000  [ 0:00:00 < -:--:-- , ? it/s ]
#    0% ------------------------------ 213/50,000  [ 0:00:00 < -:--:-- , ? it/s ]
#    1% -------------------------- 443/50,000  [ 0:00:00 < 0:00:24 , 2,091 it/s ]
#    1% -------------------------- 668/50,000  [ 0:00:00 < 0:00:23 , 2,241 it/s ]
# [Safety Layer] Triggered 100 times
#    1% -------------------------- 668/50,000  [ 0:00:00 < 0:00:23 , 2,241 it/s ]
#    2% -------------------------- 891/50,000  [ 0:00:00 < 0:00:23 , 2,166 it/s ]
#    2%  ----------------------- 1,112/50,000  [ 0:00:00 < 0:00:23 , 2,214 it/s ]
#    3%  ----------------------- 1,330/50,000  [ 0:00:00 < 0:00:23 , 2,165 it/s ]
#    3%  ----------------------- 1,545/50,000  [ 0:00:00 < 0:00:23 , 2,131 it/s ]
#    4%  ----------------------- 1,756/50,000  [ 0:00:00 < 0:00:23 , 2,099 it/s ]
# -----------------------------
# | time/              |      |
# |    fps             | 2106 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
#    4%  ----------------------- 1,756/50,000  [ 0:00:00 < 0:00:23 , 2,099 it/s ]
#    4%  ----------------------- 1,983/50,000  [ 0:00:00 < 0:00:23 , 2,138 it/s ]
#    4%  ----------------------- 1,983/50,000  [ 0:00:01 < 0:00:23 , 2,138 it/s ]
#    4%  ----------------------- 1,983/50,000  [ 0:00:01 < 0:00:23 , 2,138 it/s ]
#    4%  ----------------------- 1,983/50,000  [ 0:00:01 < 0:00:23 , 2,138 it/s ]
#    4%  ----------------------- 1,983/50,000  [ 0:00:01 < 0:00:23 , 2,138 it/s ]
#    4%  ----------------------- 1,983/50,000  [ 0:00:01 < 0:00:23 , 2,138 it/s ]
#    4%  ----------------------- 1,983/50,000  [ 0:00:01 < 0:00:23 , 2,138 it/s ]
#    4%  ----------------------- 1,983/50,000  [ 0:00:01 < 0:00:23 , 2,138 it/s ]
#    4%  ----------------------- 1,983/50,000  [ 0:00:01 < 0:00:23 , 2,138 it/s ]
#    4% - ---------------------- 2,197/50,000  [ 0:00:01 < 0:00:45 , 1,085 it/s ]
#    5% - ---------------------- 2,356/50,000  [ 0:00:02 < 0:00:43 , 1,115 it/s ]
#    5% - ---------------------- 2,574/50,000  [ 0:00:02 < 0:00:41 , 1,171 it/s ]
#    6% - ---------------------- 2,799/50,000  [ 0:00:02 < 0:00:39 , 1,217 it/s ]
#    6% - ---------------------- 3,030/50,000  [ 0:00:02 < 0:00:37 , 1,269 it/s ]
#    7% - ---------------------- 3,259/50,000  [ 0:00:02 < 0:00:36 , 1,308 it/s ]
#    7% - ---------------------- 3,486/50,000  [ 0:00:02 < 0:00:35 , 1,351 it/s ]
#    7% - ---------------------- 3,712/50,000  [ 0:00:02 < 0:00:34 , 1,382 it/s ]
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1461         |
# |    iterations           | 2            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0059908326 |
# |    clip_fraction        | 0.0307       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -0.0204      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.35         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00509     |
# |    std                  | 0.999        |
# |    value_loss           | 9.59         |
# ------------------------------------------
#    7% - ---------------------- 3,712/50,000  [ 0:00:02 < 0:00:34 , 1,382 it/s ]
#    8% - ---------------------- 3,943/50,000  [ 0:00:02 < 0:00:33 , 1,421 it/s ]
#    8% - ---------------------- 3,943/50,000  [ 0:00:02 < 0:00:33 , 1,421 it/s ]
#    8% - ---------------------- 3,943/50,000  [ 0:00:03 < 0:00:33 , 1,421 it/s ]
#    8% - ---------------------- 3,943/50,000  [ 0:00:03 < 0:00:33 , 1,421 it/s ]
#    8% - ---------------------- 3,943/50,000  [ 0:00:03 < 0:00:33 , 1,421 it/s ]
#    8% - ---------------------- 3,943/50,000  [ 0:00:03 < 0:00:33 , 1,421 it/s ]
#    8% - ---------------------- 3,943/50,000  [ 0:00:03 < 0:00:33 , 1,421 it/s ]
#    8% - ---------------------- 3,943/50,000  [ 0:00:03 < 0:00:33 , 1,421 it/s ]
#    8% - ---------------------- 3,943/50,000  [ 0:00:03 < 0:00:33 , 1,421 it/s ]
#    8% - ---------------------- 4,165/50,000  [ 0:00:03 < 0:00:43 , 1,090 it/s ]
# [Safety Layer] Triggered 200 times
#    8% - ---------------------- 4,165/50,000  [ 0:00:03 < 0:00:43 , 1,090 it/s ]
#    9% -- --------------------- 4,348/50,000  [ 0:00:03 < 0:00:42 , 1,107 it/s ]
#    9% -- --------------------- 4,516/50,000  [ 0:00:03 < 0:00:41 , 1,124 it/s ]
# [Safety Layer] Triggered 300 times
#    9% -- --------------------- 4,516/50,000  [ 0:00:03 < 0:00:41 , 1,124 it/s ]
# [Safety Layer] Triggered 400 times
#    9% -- --------------------- 4,516/50,000  [ 0:00:03 < 0:00:41 , 1,124 it/s ]
#    9% -- --------------------- 4,737/50,000  [ 0:00:04 < 0:00:40 , 1,153 it/s ]
# [Safety Layer] Triggered 500 times
#    9% -- --------------------- 4,737/50,000  [ 0:00:04 < 0:00:40 , 1,153 it/s ]
# Step   5000 | Episodes:   10 | Avg Reward (last 10): 28.02
#    9% -- --------------------- 4,737/50,000  [ 0:00:04 < 0:00:40 , 1,153 it/s ]
#   10% -- --------------------- 4,957/50,000  [ 0:00:04 < 0:00:39 , 1,177 it/s ]
#   10% -- --------------------- 5,179/50,000  [ 0:00:04 < 0:00:38 , 1,204 it/s ]
#   11% -- --------------------- 5,412/50,000  [ 0:00:04 < 0:00:37 , 1,228 it/s ]
# [Safety Layer] Triggered 600 times
#   11% -- --------------------- 5,412/50,000  [ 0:00:04 < 0:00:37 , 1,228 it/s ]
#   11% -- --------------------- 5,642/50,000  [ 0:00:04 < 0:00:36 , 1,254 it/s ]
# [Safety Layer] Triggered 700 times
#   11% -- --------------------- 5,642/50,000  [ 0:00:04 < 0:00:36 , 1,254 it/s ]
#   12% -- --------------------- 5,871/50,000  [ 0:00:04 < 0:00:35 , 1,275 it/s ]
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1316        |
# |    iterations           | 3           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.005564238 |
# |    clip_fraction        | 0.0803      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | -0.448      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.617       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00839    |
# |    std                  | 1.01        |
# |    value_loss           | 1.34        |
# -----------------------------------------
#   12% -- --------------------- 5,871/50,000  [ 0:00:04 < 0:00:35 , 1,275 it/s ]
#   12% -- --------------------- 6,097/50,000  [ 0:00:04 < 0:00:34 , 1,299 it/s ]
#   12% -- --------------------- 6,097/50,000  [ 0:00:04 < 0:00:34 , 1,299 it/s ]
#   12% -- --------------------- 6,097/50,000  [ 0:00:04 < 0:00:34 , 1,299 it/s ]
#   12% -- --------------------- 6,097/50,000  [ 0:00:05 < 0:00:34 , 1,299 it/s ]
#   12% -- --------------------- 6,097/50,000  [ 0:00:05 < 0:00:34 , 1,299 it/s ]
#   12% -- --------------------- 6,097/50,000  [ 0:00:05 < 0:00:34 , 1,299 it/s ]
#   12% -- --------------------- 6,097/50,000  [ 0:00:05 < 0:00:34 , 1,299 it/s ]
#   12% -- --------------------- 6,097/50,000  [ 0:00:05 < 0:00:34 , 1,299 it/s ]
#   13% --- -------------------- 6,319/50,000  [ 0:00:05 < 0:00:40 , 1,116 it/s ]
#   13% --- -------------------- 6,491/50,000  [ 0:00:05 < 0:00:39 , 1,125 it/s ]
# [Safety Layer] Triggered 800 times
#   13% --- -------------------- 6,491/50,000  [ 0:00:05 < 0:00:39 , 1,125 it/s ]
#   13% --- -------------------- 6,682/50,000  [ 0:00:05 < 0:00:38 , 1,141 it/s ]
# [Safety Layer] Triggered 900 times
#   13% --- -------------------- 6,682/50,000  [ 0:00:05 < 0:00:38 , 1,141 it/s ]
# [Safety Layer] Triggered 1000 times
#   13% --- -------------------- 6,682/50,000  [ 0:00:05 < 0:00:38 , 1,141 it/s ]
#   14% --- -------------------- 6,878/50,000  [ 0:00:05 < 0:00:38 , 1,156 it/s ]
#   14% --- -------------------- 7,091/50,000  [ 0:00:06 < 0:00:37 , 1,171 it/s ]
# [Safety Layer] Triggered 1100 times
#   14% --- -------------------- 7,091/50,000  [ 0:00:06 < 0:00:37 , 1,171 it/s ]
#   15% --- -------------------- 7,314/50,000  [ 0:00:06 < 0:00:36 , 1,190 it/s ]
#   15% --- -------------------- 7,543/50,000  [ 0:00:06 < 0:00:36 , 1,206 it/s ]
# [Safety Layer] Triggered 1200 times
#   15% --- -------------------- 7,543/50,000  [ 0:00:06 < 0:00:36 , 1,206 it/s ]
#   16% --- -------------------- 7,771/50,000  [ 0:00:06 < 0:00:35 , 1,225 it/s ]
# [Safety Layer] Triggered 1300 times
#   16% --- -------------------- 7,771/50,000  [ 0:00:06 < 0:00:35 , 1,225 it/s ]
#   16% --- -------------------- 7,985/50,000  [ 0:00:06 < 0:00:34 , 1,237 it/s ]
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1263         |
# |    iterations           | 4            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0042272704 |
# |    clip_fraction        | 0.0255       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.201        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.15         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00278     |
# |    std                  | 1.02         |
# |    value_loss           | 16.7         |
# ------------------------------------------
#   16% --- -------------------- 7,985/50,000  [ 0:00:06 < 0:00:34 , 1,237 it/s ]
#   16% --- -------------------- 7,985/50,000  [ 0:00:06 < 0:00:34 , 1,237 it/s ]
#   16% --- -------------------- 7,985/50,000  [ 0:00:06 < 0:00:34 , 1,237 it/s ]
#   16% --- -------------------- 7,985/50,000  [ 0:00:06 < 0:00:34 , 1,237 it/s ]
#   16% --- -------------------- 7,985/50,000  [ 0:00:06 < 0:00:34 , 1,237 it/s ]
#   16% --- -------------------- 7,985/50,000  [ 0:00:06 < 0:00:34 , 1,237 it/s ]
#   16% --- -------------------- 7,985/50,000  [ 0:00:07 < 0:00:34 , 1,237 it/s ]
#   16% --- -------------------- 7,985/50,000  [ 0:00:07 < 0:00:34 , 1,237 it/s ]
#   16% --- -------------------- 7,985/50,000  [ 0:00:07 < 0:00:34 , 1,237 it/s ]
#   16% --- -------------------- 8,195/50,000  [ 0:00:07 < 0:00:38 , 1,101 it/s ]
# [Safety Layer] Triggered 1400 times
#   16% --- -------------------- 8,195/50,000  [ 0:00:07 < 0:00:38 , 1,101 it/s ]
#   17% ---- ------------------- 8,385/50,000  [ 0:00:07 < 0:00:38 , 1,113 it/s ]
#   17% ---- ------------------- 8,573/50,000  [ 0:00:07 < 0:00:37 , 1,122 it/s ]
# [Safety Layer] Triggered 1500 times
#   17% ---- ------------------- 8,573/50,000  [ 0:00:07 < 0:00:37 , 1,122 it/s ]
# [Safety Layer] Triggered 1600 times
#   17% ---- ------------------- 8,573/50,000  [ 0:00:07 < 0:00:37 , 1,122 it/s ]
#   18% ---- ------------------- 8,804/50,000  [ 0:00:07 < 0:00:37 , 1,138 it/s ]
#   18% ---- ------------------- 9,025/50,000  [ 0:00:07 < 0:00:36 , 1,151 it/s ]
# [Safety Layer] Triggered 1700 times
#   18% ---- ------------------- 9,025/50,000  [ 0:00:07 < 0:00:36 , 1,151 it/s ]
#   18% ---- ------------------- 9,248/50,000  [ 0:00:07 < 0:00:35 , 1,166 it/s ]
#   19% ---- ------------------- 9,475/50,000  [ 0:00:08 < 0:00:35 , 1,178 it/s ]
#   20% ---- ------------------- 9,942/50,000  [ 0:00:08 < 0:00:34 , 1,209 it/s ]
# Step  10000 | Episodes:   20 | Avg Reward (last 10): 17.02
#   20% ---- ------------------- 9,942/50,000  [ 0:00:08 < 0:00:34 , 1,209 it/s ]
#   20% ---- ------------------ 10,168/50,000  [ 0:00:08 < 0:00:33 , 1,221 it/s ]
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1233         |
# |    iterations           | 5            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0019351036 |
# |    clip_fraction        | 0.00327      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.743        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.07         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00118     |
# |    std                  | 1.01         |
# |    value_loss           | 12.1         |
# ------------------------------------------
#   20% ---- ------------------ 10,168/50,000  [ 0:00:08 < 0:00:33 , 1,221 it/s ]
#   20% ---- ------------------ 10,168/50,000  [ 0:00:08 < 0:00:33 , 1,221 it/s ]
#   20% ---- ------------------ 10,168/50,000  [ 0:00:08 < 0:00:33 , 1,221 it/s ]
#   20% ---- ------------------ 10,168/50,000  [ 0:00:08 < 0:00:33 , 1,221 it/s ]
#   20% ---- ------------------ 10,168/50,000  [ 0:00:08 < 0:00:33 , 1,221 it/s ]
#   20% ---- ------------------ 10,168/50,000  [ 0:00:08 < 0:00:33 , 1,221 it/s ]
#   20% ---- ------------------ 10,168/50,000  [ 0:00:08 < 0:00:33 , 1,221 it/s ]
#   20% ---- ------------------ 10,168/50,000  [ 0:00:09 < 0:00:33 , 1,221 it/s ]
#   20% ---- ------------------ 10,168/50,000  [ 0:00:09 < 0:00:33 , 1,221 it/s ]
#   20% ---- ------------------ 10,168/50,000  [ 0:00:09 < 0:00:33 , 1,221 it/s ]
#   21% ---- ------------------ 10,392/50,000  [ 0:00:09 < 0:00:36 , 1,116 it/s ]
# [Safety Layer] Triggered 1800 times
#   21% ---- ------------------ 10,392/50,000  [ 0:00:09 < 0:00:36 , 1,116 it/s ]
#   22% ---- ------------------ 10,816/50,000  [ 0:00:09 < 0:00:35 , 1,137 it/s ]
# [Safety Layer] Triggered 1900 times
#   22% ---- ------------------ 10,816/50,000  [ 0:00:09 < 0:00:35 , 1,137 it/s ]
#   22% ----- ----------------- 11,039/50,000  [ 0:00:09 < 0:00:34 , 1,147 it/s ]
#   23% ----- ----------------- 11,264/50,000  [ 0:00:09 < 0:00:34 , 1,159 it/s ]
#   23% ----- ----------------- 11,488/50,000  [ 0:00:09 < 0:00:33 , 1,169 it/s ]
#   23% ----- ----------------- 11,699/50,000  [ 0:00:09 < 0:00:33 , 1,180 it/s ]
# [Safety Layer] Triggered 2000 times
#   23% ----- ----------------- 11,699/50,000  [ 0:00:09 < 0:00:33 , 1,180 it/s ]
# [Safety Layer] Triggered 2100 times
#   23% ----- ----------------- 11,699/50,000  [ 0:00:09 < 0:00:33 , 1,180 it/s ]
#   24% ----- ----------------- 11,907/50,000  [ 0:00:09 < 0:00:33 , 1,188 it/s ]
#   24% ----- ----------------- 12,114/50,000  [ 0:00:10 < 0:00:32 , 1,196 it/s ]
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1211         |
# |    iterations           | 6            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0036259126 |
# |    clip_fraction        | 0.0388       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.702        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.37         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00481     |
# |    std                  | 1.02         |
# |    value_loss           | 20.8         |
# ------------------------------------------
#   24% ----- ----------------- 12,114/50,000  [ 0:00:10 < 0:00:32 , 1,196 it/s ]
#   24% ----- ----------------- 12,114/50,000  [ 0:00:10 < 0:00:32 , 1,196 it/s ]
#   24% ----- ----------------- 12,114/50,000  [ 0:00:10 < 0:00:32 , 1,196 it/s ]
#   24% ----- ----------------- 12,114/50,000  [ 0:00:10 < 0:00:32 , 1,196 it/s ]
#   24% ----- ----------------- 12,114/50,000  [ 0:00:10 < 0:00:32 , 1,196 it/s ]
#   24% ----- ----------------- 12,114/50,000  [ 0:00:10 < 0:00:32 , 1,196 it/s ]
#   24% ----- ----------------- 12,114/50,000  [ 0:00:10 < 0:00:32 , 1,196 it/s ]
#   24% ----- ----------------- 12,114/50,000  [ 0:00:10 < 0:00:32 , 1,196 it/s ]
#   24% ----- ----------------- 12,114/50,000  [ 0:00:10 < 0:00:32 , 1,196 it/s ]
# [Safety Layer] Triggered 2200 times
#   24% ----- ----------------- 12,114/50,000  [ 0:00:10 < 0:00:32 , 1,196 it/s ]
# [Safety Layer] Triggered 2300 times
#   24% ----- ----------------- 12,114/50,000  [ 0:00:10 < 0:00:32 , 1,196 it/s ]
#   25% ----- ----------------- 12,317/50,000  [ 0:00:11 < 0:00:34 , 1,113 it/s ]
#   25% ----- ----------------- 12,512/50,000  [ 0:00:11 < 0:00:34 , 1,121 it/s ]
#   25% ----- ----------------- 12,718/50,000  [ 0:00:11 < 0:00:33 , 1,130 it/s ]
#   26% ------ ---------------- 13,195/50,000  [ 0:00:11 < 0:00:32 , 1,152 it/s ]
# [Safety Layer] Triggered 2400 times
#   26% ------ ---------------- 13,195/50,000  [ 0:00:11 < 0:00:32 , 1,152 it/s ]
# [Safety Layer] Triggered 2500 times
#   26% ------ ---------------- 13,195/50,000  [ 0:00:11 < 0:00:32 , 1,152 it/s ]
#   27% ------ ---------------- 13,413/50,000  [ 0:00:11 < 0:00:32 , 1,160 it/s ]
#   27% ------ ---------------- 13,630/50,000  [ 0:00:11 < 0:00:32 , 1,170 it/s ]
#   28% ------ ---------------- 13,855/50,000  [ 0:00:11 < 0:00:31 , 1,178 it/s ]
#   28% ------ ---------------- 14,085/50,000  [ 0:00:11 < 0:00:31 , 1,188 it/s ]
# [Safety Layer] Triggered 2600 times
#   28% ------ ---------------- 14,085/50,000  [ 0:00:11 < 0:00:31 , 1,188 it/s ]
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1204         |
# |    iterations           | 7            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0034893341 |
# |    clip_fraction        | 0.0295       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.814        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.58         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00257     |
# |    std                  | 1.03         |
# |    value_loss           | 11.1         |
# ------------------------------------------
#   28% ------ ---------------- 14,085/50,000  [ 0:00:11 < 0:00:31 , 1,188 it/s ]
#   29% ------ ---------------- 14,305/50,000  [ 0:00:11 < 0:00:30 , 1,198 it/s ]
#   29% ------ ---------------- 14,305/50,000  [ 0:00:12 < 0:00:30 , 1,198 it/s ]
#   29% ------ ---------------- 14,305/50,000  [ 0:00:12 < 0:00:30 , 1,198 it/s ]
#   29% ------ ---------------- 14,305/50,000  [ 0:00:12 < 0:00:30 , 1,198 it/s ]
#   29% ------ ---------------- 14,305/50,000  [ 0:00:12 < 0:00:30 , 1,198 it/s ]
#   29% ------ ---------------- 14,305/50,000  [ 0:00:12 < 0:00:30 , 1,198 it/s ]
#   29% ------ ---------------- 14,305/50,000  [ 0:00:12 < 0:00:30 , 1,198 it/s ]
#   29% ------ ---------------- 14,305/50,000  [ 0:00:12 < 0:00:30 , 1,198 it/s ]
#   29% ------ ---------------- 14,305/50,000  [ 0:00:12 < 0:00:30 , 1,198 it/s ]
# [Safety Layer] Triggered 2700 times
#   29% ------ ---------------- 14,305/50,000  [ 0:00:12 < 0:00:30 , 1,198 it/s ]
# [Safety Layer] Triggered 2800 times
#   29% ------ ---------------- 14,305/50,000  [ 0:00:12 < 0:00:30 , 1,198 it/s ]
#   29% ------ ---------------- 14,305/50,000  [ 0:00:12 < 0:00:30 , 1,198 it/s ]
#   29% ------ ---------------- 14,524/50,000  [ 0:00:12 < 0:00:32 , 1,120 it/s ]
# [Safety Layer] Triggered 2900 times
#   29% ------ ---------------- 14,524/50,000  [ 0:00:12 < 0:00:32 , 1,120 it/s ]
# [Safety Layer] Triggered 3000 times
#   29% ------ ---------------- 14,524/50,000  [ 0:00:12 < 0:00:32 , 1,120 it/s ]
#   29% ------ ---------------- 14,722/50,000  [ 0:00:13 < 0:00:32 , 1,126 it/s ]
# Step  15000 | Episodes:   30 | Avg Reward (last 10): 44.88
#   29% ------ ---------------- 14,722/50,000  [ 0:00:13 < 0:00:32 , 1,126 it/s ]
#   30% ------ ---------------- 14,944/50,000  [ 0:00:13 < 0:00:31 , 1,134 it/s ]
# [Safety Layer] Triggered 3100 times
#   30% ------ ---------------- 14,944/50,000  [ 0:00:13 < 0:00:31 , 1,134 it/s ]
# [Safety Layer] Triggered 3200 times
#   30% ------ ---------------- 14,944/50,000  [ 0:00:13 < 0:00:31 , 1,134 it/s ]
#   31% ------- --------------- 15,406/50,000  [ 0:00:13 < 0:00:31 , 1,152 it/s ]
# [Safety Layer] Triggered 3300 times
#   31% ------- --------------- 15,406/50,000  [ 0:00:13 < 0:00:31 , 1,152 it/s ]
#   31% ------- --------------- 15,632/50,000  [ 0:00:13 < 0:00:30 , 1,161 it/s ]
# [Safety Layer] Triggered 3400 times
#   31% ------- --------------- 15,632/50,000  [ 0:00:13 < 0:00:30 , 1,161 it/s ]
#   32% ------- --------------- 15,863/50,000  [ 0:00:13 < 0:00:30 , 1,169 it/s ]
#   32% ------- --------------- 16,083/50,000  [ 0:00:13 < 0:00:29 , 1,177 it/s ]
# [Safety Layer] Triggered 3500 times
#   32% ------- --------------- 16,083/50,000  [ 0:00:13 < 0:00:29 , 1,177 it/s ]
#   33% ------- --------------- 16,306/50,000  [ 0:00:13 < 0:00:29 , 1,184 it/s ]
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1192         |
# |    iterations           | 8            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0054368265 |
# |    clip_fraction        | 0.0351       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.45        |
# |    explained_variance   | 0.881        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.66         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00282     |
# |    std                  | 1.03         |
# |    value_loss           | 8.14         |
# ------------------------------------------
#   33% ------- --------------- 16,306/50,000  [ 0:00:13 < 0:00:29 , 1,184 it/s ]
#   33% ------- --------------- 16,306/50,000  [ 0:00:13 < 0:00:29 , 1,184 it/s ]
#   33% ------- --------------- 16,306/50,000  [ 0:00:13 < 0:00:29 , 1,184 it/s ]
#   33% ------- --------------- 16,306/50,000  [ 0:00:14 < 0:00:29 , 1,184 it/s ]
#   33% ------- --------------- 16,306/50,000  [ 0:00:14 < 0:00:29 , 1,184 it/s ]
#   33% ------- --------------- 16,306/50,000  [ 0:00:14 < 0:00:29 , 1,184 it/s ]
#   33% ------- --------------- 16,306/50,000  [ 0:00:14 < 0:00:29 , 1,184 it/s ]
#   33% ------- --------------- 16,306/50,000  [ 0:00:14 < 0:00:29 , 1,184 it/s ]
# [Safety Layer] Triggered 3600 times
#   33% ------- --------------- 16,306/50,000  [ 0:00:14 < 0:00:29 , 1,184 it/s ]
#   33% ------- --------------- 16,306/50,000  [ 0:00:14 < 0:00:29 , 1,184 it/s ]
#   33% ------- --------------- 16,526/50,000  [ 0:00:14 < 0:00:30 , 1,124 it/s ]
# [Safety Layer] Triggered 3700 times
#   33% ------- --------------- 16,526/50,000  [ 0:00:14 < 0:00:30 , 1,124 it/s ]
#   33% ------- --------------- 16,721/50,000  [ 0:00:14 < 0:00:30 , 1,130 it/s ]
# [Safety Layer] Triggered 3800 times
#   33% ------- --------------- 16,721/50,000  [ 0:00:14 < 0:00:30 , 1,130 it/s ]
#   34% ------- --------------- 16,942/50,000  [ 0:00:14 < 0:00:30 , 1,137 it/s ]
# [Safety Layer] Triggered 3900 times
#   34% ------- --------------- 16,942/50,000  [ 0:00:14 < 0:00:30 , 1,137 it/s ]
# [Safety Layer] Triggered 4000 times
#   34% ------- --------------- 16,942/50,000  [ 0:00:14 < 0:00:30 , 1,137 it/s ]
#   34% ------- --------------- 17,169/50,000  [ 0:00:15 < 0:00:29 , 1,145 it/s ]
# [Safety Layer] Triggered 4100 times
#   34% ------- --------------- 17,169/50,000  [ 0:00:15 < 0:00:29 , 1,145 it/s ]
#   35% ------- --------------- 17,389/50,000  [ 0:00:15 < 0:00:29 , 1,151 it/s ]
# [Safety Layer] Triggered 4200 times
#   35% ------- --------------- 17,389/50,000  [ 0:00:15 < 0:00:29 , 1,151 it/s ]
#   36% -------- -------------- 17,847/50,000  [ 0:00:15 < 0:00:28 , 1,167 it/s ]
# [Safety Layer] Triggered 4300 times
#   36% -------- -------------- 17,847/50,000  [ 0:00:15 < 0:00:28 , 1,167 it/s ]
#   36% -------- -------------- 18,068/50,000  [ 0:00:15 < 0:00:28 , 1,173 it/s ]
# [Safety Layer] Triggered 4400 times
#   36% -------- -------------- 18,068/50,000  [ 0:00:15 < 0:00:28 , 1,173 it/s ]
# [Safety Layer] Triggered 4500 times
#   36% -------- -------------- 18,068/50,000  [ 0:00:15 < 0:00:28 , 1,173 it/s ]
#   37% -------- -------------- 18,298/50,000  [ 0:00:15 < 0:00:27 , 1,181 it/s ]
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1189         |
# |    iterations           | 9            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0047627594 |
# |    clip_fraction        | 0.0546       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.881        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.26         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00382     |
# |    std                  | 1.01         |
# |    value_loss           | 10.4         |
# ------------------------------------------
#   37% -------- -------------- 18,298/50,000  [ 0:00:15 < 0:00:27 , 1,181 it/s ]
#   37% -------- -------------- 18,298/50,000  [ 0:00:15 < 0:00:27 , 1,181 it/s ]
#   37% -------- -------------- 18,298/50,000  [ 0:00:15 < 0:00:27 , 1,181 it/s ]
#   37% -------- -------------- 18,298/50,000  [ 0:00:15 < 0:00:27 , 1,181 it/s ]
#   37% -------- -------------- 18,298/50,000  [ 0:00:15 < 0:00:27 , 1,181 it/s ]
#   37% -------- -------------- 18,298/50,000  [ 0:00:15 < 0:00:27 , 1,181 it/s ]
#   37% -------- -------------- 18,298/50,000  [ 0:00:16 < 0:00:27 , 1,181 it/s ]
#   37% -------- -------------- 18,298/50,000  [ 0:00:16 < 0:00:27 , 1,181 it/s ]
#   37% -------- -------------- 18,298/50,000  [ 0:00:16 < 0:00:27 , 1,181 it/s ]
# [Safety Layer] Triggered 4600 times
#   37% -------- -------------- 18,298/50,000  [ 0:00:16 < 0:00:27 , 1,181 it/s ]
#   37% -------- -------------- 18,519/50,000  [ 0:00:16 < 0:00:28 , 1,125 it/s ]
#   37% -------- -------------- 18,711/50,000  [ 0:00:16 < 0:00:28 , 1,131 it/s ]
# [Safety Layer] Triggered 4700 times
#   37% -------- -------------- 18,711/50,000  [ 0:00:16 < 0:00:28 , 1,131 it/s ]
# [Safety Layer] Triggered 4800 times
#   37% -------- -------------- 18,711/50,000  [ 0:00:16 < 0:00:28 , 1,131 it/s ]
#   38% -------- -------------- 18,919/50,000  [ 0:00:16 < 0:00:28 , 1,137 it/s ]
#   38% -------- -------------- 19,145/50,000  [ 0:00:16 < 0:00:27 , 1,143 it/s ]
# [Safety Layer] Triggered 4900 times
#   38% -------- -------------- 19,145/50,000  [ 0:00:16 < 0:00:27 , 1,143 it/s ]
#   39% -------- -------------- 19,377/50,000  [ 0:00:16 < 0:00:27 , 1,151 it/s ]
#   39% --------- ------------- 19,591/50,000  [ 0:00:16 < 0:00:27 , 1,156 it/s ]
# Step  20000 | Episodes:   40 | Avg Reward (last 10): 25.41
#   39% --------- ------------- 19,591/50,000  [ 0:00:16 < 0:00:27 , 1,156 it/s ]
#   40% --------- ------------- 19,824/50,000  [ 0:00:17 < 0:00:26 , 1,163 it/s ]
#   40% --------- ------------- 20,051/50,000  [ 0:00:17 < 0:00:26 , 1,169 it/s ]
# [Safety Layer] Triggered 5000 times
#   40% --------- ------------- 20,051/50,000  [ 0:00:17 < 0:00:26 , 1,169 it/s ]
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1186         |
# |    iterations           | 10           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0056610336 |
# |    clip_fraction        | 0.0386       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.871        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.1         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.0022      |
# |    std                  | 1            |
# |    value_loss           | 11.8         |
# ------------------------------------------
#   40% --------- ------------- 20,051/50,000  [ 0:00:17 < 0:00:26 , 1,169 it/s ]
#   41% --------- ------------- 20,286/50,000  [ 0:00:17 < 0:00:26 , 1,176 it/s ]
#   41% --------- ------------- 20,286/50,000  [ 0:00:17 < 0:00:26 , 1,176 it/s ]
#   41% --------- ------------- 20,286/50,000  [ 0:00:17 < 0:00:26 , 1,176 it/s ]
#   41% --------- ------------- 20,286/50,000  [ 0:00:17 < 0:00:26 , 1,176 it/s ]
#   41% --------- ------------- 20,286/50,000  [ 0:00:17 < 0:00:26 , 1,176 it/s ]
#   41% --------- ------------- 20,286/50,000  [ 0:00:17 < 0:00:26 , 1,176 it/s ]
#   41% --------- ------------- 20,286/50,000  [ 0:00:17 < 0:00:26 , 1,176 it/s ]
#   41% --------- ------------- 20,286/50,000  [ 0:00:18 < 0:00:26 , 1,176 it/s ]
#   41% --------- ------------- 20,509/50,000  [ 0:00:18 < 0:00:27 , 1,131 it/s ]
#   41% --------- ------------- 20,710/50,000  [ 0:00:18 < 0:00:26 , 1,135 it/s ]
#   42% --------- ------------- 20,917/50,000  [ 0:00:18 < 0:00:26 , 1,140 it/s ]
# [Safety Layer] Triggered 5100 times
#   42% --------- ------------- 20,917/50,000  [ 0:00:18 < 0:00:26 , 1,140 it/s ]
#   42% --------- ------------- 21,128/50,000  [ 0:00:18 < 0:00:26 , 1,145 it/s ]
# [Safety Layer] Triggered 5200 times
#   42% --------- ------------- 21,128/50,000  [ 0:00:18 < 0:00:26 , 1,145 it/s ]
# [Safety Layer] Triggered 5300 times
#   42% --------- ------------- 21,128/50,000  [ 0:00:18 < 0:00:26 , 1,145 it/s ]
#   43% --------- ------------- 21,348/50,000  [ 0:00:18 < 0:00:25 , 1,151 it/s ]
#   44% ---------- ------------ 21,814/50,000  [ 0:00:18 < 0:00:25 , 1,164 it/s ]
# [Safety Layer] Triggered 5400 times
#   44% ---------- ------------ 21,814/50,000  [ 0:00:18 < 0:00:25 , 1,164 it/s ]
#   44% ---------- ------------ 22,038/50,000  [ 0:00:18 < 0:00:24 , 1,170 it/s ]
#   45% ---------- ------------ 22,261/50,000  [ 0:00:18 < 0:00:24 , 1,175 it/s ]
# [Safety Layer] Triggered 5500 times
#   45% ---------- ------------ 22,261/50,000  [ 0:00:18 < 0:00:24 , 1,175 it/s ]
# [Safety Layer] Triggered 5600 times
#   45% ---------- ------------ 22,261/50,000  [ 0:00:18 < 0:00:24 , 1,175 it/s ]
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1186         |
# |    iterations           | 11           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0044440255 |
# |    clip_fraction        | 0.0295       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.849        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.6         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00244     |
# |    std                  | 1.01         |
# |    value_loss           | 13.7         |
# ------------------------------------------
#   45% ---------- ------------ 22,261/50,000  [ 0:00:18 < 0:00:24 , 1,175 it/s ]
#   45% ---------- ------------ 22,485/50,000  [ 0:00:18 < 0:00:24 , 1,181 it/s ]
#   45% ---------- ------------ 22,485/50,000  [ 0:00:19 < 0:00:24 , 1,181 it/s ]
#   45% ---------- ------------ 22,485/50,000  [ 0:00:19 < 0:00:24 , 1,181 it/s ]
#   45% ---------- ------------ 22,485/50,000  [ 0:00:19 < 0:00:24 , 1,181 it/s ]
#   45% ---------- ------------ 22,485/50,000  [ 0:00:19 < 0:00:24 , 1,181 it/s ]
#   45% ---------- ------------ 22,485/50,000  [ 0:00:19 < 0:00:24 , 1,181 it/s ]
#   45% ---------- ------------ 22,485/50,000  [ 0:00:19 < 0:00:24 , 1,181 it/s ]
#   45% ---------- ------------ 22,485/50,000  [ 0:00:19 < 0:00:24 , 1,181 it/s ]
#   45% ---------- ------------ 22,706/50,000  [ 0:00:19 < 0:00:24 , 1,139 it/s ]
# [Safety Layer] Triggered 5700 times
#   45% ---------- ------------ 22,706/50,000  [ 0:00:19 < 0:00:24 , 1,139 it/s ]
#   46% ---------- ------------ 22,903/50,000  [ 0:00:19 < 0:00:24 , 1,142 it/s ]
#   46% ---------- ------------ 23,128/50,000  [ 0:00:20 < 0:00:24 , 1,148 it/s ]
#   47% ---------- ------------ 23,365/50,000  [ 0:00:20 < 0:00:24 , 1,155 it/s ]
#   47% ---------- ------------ 23,597/50,000  [ 0:00:20 < 0:00:23 , 1,160 it/s ]
# [Safety Layer] Triggered 5800 times
#   47% ---------- ------------ 23,597/50,000  [ 0:00:20 < 0:00:23 , 1,160 it/s ]
# [Safety Layer] Triggered 5900 times
#   47% ---------- ------------ 23,597/50,000  [ 0:00:20 < 0:00:23 , 1,160 it/s ]
#   48% ---------- ------------ 23,822/50,000  [ 0:00:20 < 0:00:23 , 1,166 it/s ]
# [Safety Layer] Triggered 6000 times
#   48% ---------- ------------ 23,822/50,000  [ 0:00:20 < 0:00:23 , 1,166 it/s ]
#   48% ----------- ----------- 24,042/50,000  [ 0:00:20 < 0:00:23 , 1,170 it/s ]
# [Safety Layer] Triggered 6100 times
#   48% ----------- ----------- 24,042/50,000  [ 0:00:20 < 0:00:23 , 1,170 it/s ]
#   49% ----------- ----------- 24,267/50,000  [ 0:00:20 < 0:00:22 , 1,176 it/s ]
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1187        |
# |    iterations           | 12          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.003486762 |
# |    clip_fraction        | 0.0273      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.882       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.26        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00165    |
# |    std                  | 0.993       |
# |    value_loss           | 11.7        |
# -----------------------------------------
#   49% ----------- ----------- 24,267/50,000  [ 0:00:20 < 0:00:22 , 1,176 it/s ]
#   49% ----------- ----------- 24,495/50,000  [ 0:00:20 < 0:00:22 , 1,182 it/s ]
#   49% ----------- ----------- 24,495/50,000  [ 0:00:20 < 0:00:22 , 1,182 it/s ]
#   49% ----------- ----------- 24,495/50,000  [ 0:00:20 < 0:00:22 , 1,182 it/s ]
#   49% ----------- ----------- 24,495/50,000  [ 0:00:21 < 0:00:22 , 1,182 it/s ]
#   49% ----------- ----------- 24,495/50,000  [ 0:00:21 < 0:00:22 , 1,182 it/s ]
#   49% ----------- ----------- 24,495/50,000  [ 0:00:21 < 0:00:22 , 1,182 it/s ]
#   49% ----------- ----------- 24,495/50,000  [ 0:00:21 < 0:00:22 , 1,182 it/s ]
#   49% ----------- ----------- 24,495/50,000  [ 0:00:21 < 0:00:22 , 1,182 it/s ]
#   49% ----------- ----------- 24,716/50,000  [ 0:00:21 < 0:00:23 , 1,143 it/s ]
# [Safety Layer] Triggered 6200 times
#   49% ----------- ----------- 24,716/50,000  [ 0:00:21 < 0:00:23 , 1,143 it/s ]
# [Safety Layer] Triggered 6300 times
#   49% ----------- ----------- 24,716/50,000  [ 0:00:21 < 0:00:23 , 1,143 it/s ]
#   50% ----------- ----------- 24,890/50,000  [ 0:00:21 < 0:00:22 , 1,145 it/s ]
# [Safety Layer] Triggered 6400 times
#   50% ----------- ----------- 24,890/50,000  [ 0:00:21 < 0:00:22 , 1,145 it/s ]
# Step  25000 | Episodes:   50 | Avg Reward (last 10): 41.42
#   50% ----------- ----------- 24,890/50,000  [ 0:00:21 < 0:00:22 , 1,145 it/s ]
#   50% ----------- ----------- 25,098/50,000  [ 0:00:21 < 0:00:22 , 1,150 it/s ]
# [Safety Layer] Triggered 6500 times
#   50% ----------- ----------- 25,098/50,000  [ 0:00:21 < 0:00:22 , 1,150 it/s ]
#   51% ----------- ----------- 25,325/50,000  [ 0:00:21 < 0:00:22 , 1,155 it/s ]
# [Safety Layer] Triggered 6600 times
#   51% ----------- ----------- 25,325/50,000  [ 0:00:21 < 0:00:22 , 1,155 it/s ]
#   51% ----------- ----------- 25,546/50,000  [ 0:00:21 < 0:00:22 , 1,160 it/s ]
# [Safety Layer] Triggered 6700 times
#   51% ----------- ----------- 25,546/50,000  [ 0:00:21 < 0:00:22 , 1,160 it/s ]
#   52% ----------- ----------- 25,780/50,000  [ 0:00:22 < 0:00:21 , 1,165 it/s ]
# [Safety Layer] Triggered 6800 times
#   52% ----------- ----------- 25,780/50,000  [ 0:00:22 < 0:00:21 , 1,165 it/s ]
#   52% ----------- ----------- 26,000/50,000  [ 0:00:22 < 0:00:21 , 1,170 it/s ]
# [Safety Layer] Triggered 6900 times
#   52% ----------- ----------- 26,000/50,000  [ 0:00:22 < 0:00:21 , 1,170 it/s ]
#   52% ------------ ---------- 26,230/50,000  [ 0:00:22 < 0:00:21 , 1,175 it/s ]
# [Safety Layer] Triggered 7000 times
#   52% ------------ ---------- 26,230/50,000  [ 0:00:22 < 0:00:21 , 1,175 it/s ]
#   53% ------------ ---------- 26,458/50,000  [ 0:00:22 < 0:00:20 , 1,180 it/s ]
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1186        |
# |    iterations           | 13          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.006713796 |
# |    clip_fraction        | 0.0479      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.899       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.91        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00162    |
# |    std                  | 1           |
# |    value_loss           | 9.39        |
# -----------------------------------------
#   53% ------------ ---------- 26,458/50,000  [ 0:00:22 < 0:00:20 , 1,180 it/s ]
#   53% ------------ ---------- 26,458/50,000  [ 0:00:22 < 0:00:20 , 1,180 it/s ]
#   53% ------------ ---------- 26,458/50,000  [ 0:00:22 < 0:00:20 , 1,180 it/s ]
#   53% ------------ ---------- 26,458/50,000  [ 0:00:22 < 0:00:20 , 1,180 it/s ]
#   53% ------------ ---------- 26,458/50,000  [ 0:00:22 < 0:00:20 , 1,180 it/s ]
#   53% ------------ ---------- 26,458/50,000  [ 0:00:22 < 0:00:20 , 1,180 it/s ]
#   53% ------------ ---------- 26,458/50,000  [ 0:00:23 < 0:00:20 , 1,180 it/s ]
#   53% ------------ ---------- 26,458/50,000  [ 0:00:23 < 0:00:20 , 1,180 it/s ]
# [Safety Layer] Triggered 7100 times
#   53% ------------ ---------- 26,458/50,000  [ 0:00:23 < 0:00:20 , 1,180 it/s ]
#   53% ------------ ---------- 26,679/50,000  [ 0:00:23 < 0:00:21 , 1,144 it/s ]
# [Safety Layer] Triggered 7200 times
#   53% ------------ ---------- 26,679/50,000  [ 0:00:23 < 0:00:21 , 1,144 it/s ]
#   54% ------------ ---------- 26,858/50,000  [ 0:00:23 < 0:00:21 , 1,147 it/s ]
# [Safety Layer] Triggered 7300 times
#   54% ------------ ---------- 26,858/50,000  [ 0:00:23 < 0:00:21 , 1,147 it/s ]
#   54% ------------ ---------- 27,048/50,000  [ 0:00:23 < 0:00:20 , 1,150 it/s ]
#   55% ------------ ---------- 27,280/50,000  [ 0:00:23 < 0:00:20 , 1,156 it/s ]
#   55% ------------ ---------- 27,502/50,000  [ 0:00:23 < 0:00:20 , 1,160 it/s ]
# [Safety Layer] Triggered 7400 times
#   55% ------------ ---------- 27,502/50,000  [ 0:00:23 < 0:00:20 , 1,160 it/s ]
#   55% ------------ ---------- 27,714/50,000  [ 0:00:23 < 0:00:20 , 1,164 it/s ]
# [Safety Layer] Triggered 7500 times
#   55% ------------ ---------- 27,714/50,000  [ 0:00:23 < 0:00:20 , 1,164 it/s ]
#   56% ------------ ---------- 27,920/50,000  [ 0:00:23 < 0:00:19 , 1,167 it/s ]
#   56% ------------ ---------- 28,135/50,000  [ 0:00:24 < 0:00:19 , 1,172 it/s ]
# [Safety Layer] Triggered 7600 times
#   56% ------------ ---------- 28,135/50,000  [ 0:00:24 < 0:00:19 , 1,172 it/s ]
#   57% ------------- --------- 28,345/50,000  [ 0:00:24 < 0:00:19 , 1,175 it/s ]
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1185         |
# |    iterations           | 14           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0038833497 |
# |    clip_fraction        | 0.038        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.882        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.91         |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00139     |
# |    std                  | 1.01         |
# |    value_loss           | 10.4         |
# ------------------------------------------
#   57% ------------- --------- 28,345/50,000  [ 0:00:24 < 0:00:19 , 1,175 it/s ]
#   57% ------------- --------- 28,561/50,000  [ 0:00:24 < 0:00:19 , 1,180 it/s ]
#   57% ------------- --------- 28,561/50,000  [ 0:00:24 < 0:00:19 , 1,180 it/s ]
#   57% ------------- --------- 28,561/50,000  [ 0:00:24 < 0:00:19 , 1,180 it/s ]
#   57% ------------- --------- 28,561/50,000  [ 0:00:24 < 0:00:19 , 1,180 it/s ]
#   57% ------------- --------- 28,561/50,000  [ 0:00:24 < 0:00:19 , 1,180 it/s ]
#   57% ------------- --------- 28,561/50,000  [ 0:00:24 < 0:00:19 , 1,180 it/s ]
#   57% ------------- --------- 28,561/50,000  [ 0:00:24 < 0:00:19 , 1,180 it/s ]
#   57% ------------- --------- 28,561/50,000  [ 0:00:24 < 0:00:19 , 1,180 it/s ]
#   58% ------------- --------- 28,772/50,000  [ 0:00:25 < 0:00:19 , 1,147 it/s ]
#   58% ------------- --------- 28,960/50,000  [ 0:00:25 < 0:00:19 , 1,149 it/s ]
# [Safety Layer] Triggered 7700 times
#   58% ------------- --------- 28,960/50,000  [ 0:00:25 < 0:00:19 , 1,149 it/s ]
#   58% ------------- --------- 29,163/50,000  [ 0:00:25 < 0:00:19 , 1,153 it/s ]
# [Safety Layer] Triggered 7800 times
#   58% ------------- --------- 29,163/50,000  [ 0:00:25 < 0:00:19 , 1,153 it/s ]
#   59% ------------- --------- 29,386/50,000  [ 0:00:25 < 0:00:18 , 1,157 it/s ]
#   59% ------------- --------- 29,613/50,000  [ 0:00:25 < 0:00:18 , 1,161 it/s ]
# Step  30000 | Episodes:   60 | Avg Reward (last 10): 54.49
#   59% ------------- --------- 29,613/50,000  [ 0:00:25 < 0:00:18 , 1,161 it/s ]
#   60% ------------- --------- 29,842/50,000  [ 0:00:25 < 0:00:18 , 1,166 it/s ]
#   60% ------------- --------- 30,070/50,000  [ 0:00:25 < 0:00:18 , 1,170 it/s ]
# [Safety Layer] Triggered 7900 times
#   60% ------------- --------- 30,070/50,000  [ 0:00:25 < 0:00:18 , 1,170 it/s ]
# [Safety Layer] Triggered 8000 times
#   60% ------------- --------- 30,070/50,000  [ 0:00:25 < 0:00:18 , 1,170 it/s ]
#   61% -------------- -------- 30,506/50,000  [ 0:00:25 < 0:00:17 , 1,178 it/s ]
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1184         |
# |    iterations           | 15           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0033972869 |
# |    clip_fraction        | 0.025        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.884        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.01         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00166     |
# |    std                  | 1.01         |
# |    value_loss           | 8.49         |
# ------------------------------------------
#   61% -------------- -------- 30,506/50,000  [ 0:00:25 < 0:00:17 , 1,178 it/s ]
#   61% -------------- -------- 30,506/50,000  [ 0:00:25 < 0:00:17 , 1,178 it/s ]
#   61% -------------- -------- 30,506/50,000  [ 0:00:26 < 0:00:17 , 1,178 it/s ]
#   61% -------------- -------- 30,506/50,000  [ 0:00:26 < 0:00:17 , 1,178 it/s ]
#   61% -------------- -------- 30,506/50,000  [ 0:00:26 < 0:00:17 , 1,178 it/s ]
#   61% -------------- -------- 30,506/50,000  [ 0:00:26 < 0:00:17 , 1,178 it/s ]
#   61% -------------- -------- 30,506/50,000  [ 0:00:26 < 0:00:17 , 1,178 it/s ]
#   61% -------------- -------- 30,506/50,000  [ 0:00:26 < 0:00:17 , 1,178 it/s ]
#   61% -------------- -------- 30,506/50,000  [ 0:00:26 < 0:00:17 , 1,178 it/s ]
# [Safety Layer] Triggered 8100 times
#   61% -------------- -------- 30,506/50,000  [ 0:00:26 < 0:00:17 , 1,178 it/s ]
#   61% -------------- -------- 30,722/50,000  [ 0:00:26 < 0:00:17 , 1,148 it/s ]
#   62% -------------- -------- 30,907/50,000  [ 0:00:26 < 0:00:17 , 1,150 it/s ]
# [Safety Layer] Triggered 8200 times
#   62% -------------- -------- 30,907/50,000  [ 0:00:26 < 0:00:17 , 1,150 it/s ]
#   63% -------------- -------- 31,318/50,000  [ 0:00:26 < 0:00:17 , 1,157 it/s ]
# [Safety Layer] Triggered 8300 times
#   63% -------------- -------- 31,318/50,000  [ 0:00:26 < 0:00:17 , 1,157 it/s ]
# [Safety Layer] Triggered 8400 times
#   63% -------------- -------- 31,318/50,000  [ 0:00:26 < 0:00:17 , 1,157 it/s ]
#   63% -------------- -------- 31,528/50,000  [ 0:00:27 < 0:00:16 , 1,160 it/s ]
#   63% -------------- -------- 31,747/50,000  [ 0:00:27 < 0:00:16 , 1,165 it/s ]
# [Safety Layer] Triggered 8500 times
#   63% -------------- -------- 31,747/50,000  [ 0:00:27 < 0:00:16 , 1,165 it/s ]
#   64% -------------- -------- 31,968/50,000  [ 0:00:27 < 0:00:16 , 1,168 it/s ]
#   64% -------------- -------- 32,195/50,000  [ 0:00:27 < 0:00:16 , 1,172 it/s ]
#   65% -------------- -------- 32,427/50,000  [ 0:00:27 < 0:00:15 , 1,176 it/s ]
#   65% --------------- ------- 32,650/50,000  [ 0:00:27 < 0:00:15 , 1,180 it/s ]
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1184         |
# |    iterations           | 16           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0023473953 |
# |    clip_fraction        | 0.0489       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.907        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.1          |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00143     |
# |    std                  | 1.04         |
# |    value_loss           | 5.85         |
# ------------------------------------------
#   65% --------------- ------- 32,650/50,000  [ 0:00:27 < 0:00:15 , 1,180 it/s ]
#   65% --------------- ------- 32,650/50,000  [ 0:00:27 < 0:00:15 , 1,180 it/s ]
#   65% --------------- ------- 32,650/50,000  [ 0:00:27 < 0:00:15 , 1,180 it/s ]
#   65% --------------- ------- 32,650/50,000  [ 0:00:27 < 0:00:15 , 1,180 it/s ]
#   65% --------------- ------- 32,650/50,000  [ 0:00:28 < 0:00:15 , 1,180 it/s ]
#   65% --------------- ------- 32,650/50,000  [ 0:00:28 < 0:00:15 , 1,180 it/s ]
#   65% --------------- ------- 32,650/50,000  [ 0:00:28 < 0:00:15 , 1,180 it/s ]
#   65% --------------- ------- 32,650/50,000  [ 0:00:28 < 0:00:15 , 1,180 it/s ]
# [Safety Layer] Triggered 8600 times
#   65% --------------- ------- 32,650/50,000  [ 0:00:28 < 0:00:15 , 1,180 it/s ]
#   66% --------------- ------- 32,869/50,000  [ 0:00:28 < 0:00:15 , 1,151 it/s ]
# [Safety Layer] Triggered 8700 times
#   66% --------------- ------- 32,869/50,000  [ 0:00:28 < 0:00:15 , 1,151 it/s ]
#   66% --------------- ------- 33,063/50,000  [ 0:00:28 < 0:00:15 , 1,154 it/s ]
#   67% --------------- ------- 33,257/50,000  [ 0:00:28 < 0:00:15 , 1,156 it/s ]
# [Safety Layer] Triggered 8800 times
#   67% --------------- ------- 33,257/50,000  [ 0:00:28 < 0:00:15 , 1,156 it/s ]
# [Safety Layer] Triggered 8900 times
#   67% --------------- ------- 33,257/50,000  [ 0:00:28 < 0:00:15 , 1,156 it/s ]
#   67% --------------- ------- 33,468/50,000  [ 0:00:28 < 0:00:15 , 1,160 it/s ]
# [Safety Layer] Triggered 9000 times
#   67% --------------- ------- 33,468/50,000  [ 0:00:28 < 0:00:15 , 1,160 it/s ]
#   67% --------------- ------- 33,697/50,000  [ 0:00:28 < 0:00:15 , 1,163 it/s ]
# [Safety Layer] Triggered 9100 times
#   67% --------------- ------- 33,697/50,000  [ 0:00:28 < 0:00:15 , 1,163 it/s ]
# [Safety Layer] Triggered 9200 times
#   67% --------------- ------- 33,697/50,000  [ 0:00:28 < 0:00:15 , 1,163 it/s ]
#   68% --------------- ------- 33,922/50,000  [ 0:00:29 < 0:00:14 , 1,167 it/s ]
#   68% --------------- ------- 34,144/50,000  [ 0:00:29 < 0:00:14 , 1,171 it/s ]
# [Safety Layer] Triggered 9300 times
#   68% --------------- ------- 34,144/50,000  [ 0:00:29 < 0:00:14 , 1,171 it/s ]
# [Safety Layer] Triggered 9400 times
#   68% --------------- ------- 34,144/50,000  [ 0:00:29 < 0:00:14 , 1,171 it/s ]
#   69% --------------- ------- 34,372/50,000  [ 0:00:29 < 0:00:14 , 1,175 it/s ]
#   69% --------------- ------- 34,598/50,000  [ 0:00:29 < 0:00:14 , 1,178 it/s ]
# [Safety Layer] Triggered 9500 times
#   69% --------------- ------- 34,598/50,000  [ 0:00:29 < 0:00:14 , 1,178 it/s ]
# ...
#   82% ------------------ ---- 40,828/50,000  [ 0:00:34 < 0:00:08 , 1,167 it/s ]
#   82% ------------------ ---- 40,828/50,000  [ 0:00:34 < 0:00:08 , 1,167 it/s ]
#   82% ------------------ ---- 40,828/50,000  [ 0:00:34 < 0:00:08 , 1,167 it/s ]
#   82% ------------------ ---- 40,828/50,000  [ 0:00:35 < 0:00:08 , 1,167 it/s ]
#   82% ------------------ ---- 40,828/50,000  [ 0:00:35 < 0:00:08 , 1,167 it/s ]
#   82% ------------------ ---- 40,828/50,000  [ 0:00:35 < 0:00:08 , 1,167 it/s ]
#   82% ------------------ ---- 41,050/50,000  [ 0:00:35 < 0:00:08 , 1,164 it/s ]
# [Safety Layer] Triggered 10800 times
#   82% ------------------ ---- 41,050/50,000  [ 0:00:35 < 0:00:08 , 1,164 it/s ]
#   82% ------------------ ---- 41,245/50,000  [ 0:00:35 < 0:00:08 , 1,167 it/s ]
# [Safety Layer] Triggered 10900 times
#   82% ------------------ ---- 41,245/50,000  [ 0:00:35 < 0:00:08 , 1,167 it/s ]
# [Safety Layer] Triggered 11000 times
#   82% ------------------ ---- 41,245/50,000  [ 0:00:35 < 0:00:08 , 1,167 it/s ]
#   83% ------------------- --- 41,446/50,000  [ 0:00:35 < 0:00:08 , 1,168 it/s ]
#   83% ------------------- --- 41,675/50,000  [ 0:00:35 < 0:00:08 , 1,169 it/s ]
# [Safety Layer] Triggered 11100 times
#   83% ------------------- --- 41,675/50,000  [ 0:00:35 < 0:00:08 , 1,169 it/s ]
# [Safety Layer] Triggered 11200 times
#   83% ------------------- --- 41,675/50,000  [ 0:00:35 < 0:00:08 , 1,169 it/s ]
#   84% ------------------- --- 41,902/50,000  [ 0:00:35 < 0:00:07 , 1,169 it/s ]
#   84% ------------------- --- 42,129/50,000  [ 0:00:35 < 0:00:07 , 1,170 it/s ]
# [Safety Layer] Triggered 11300 times
#   84% ------------------- --- 42,129/50,000  [ 0:00:35 < 0:00:07 , 1,170 it/s ]
# [Safety Layer] Triggered 11400 times
#   84% ------------------- --- 42,129/50,000  [ 0:00:35 < 0:00:07 , 1,170 it/s ]
#   85% ------------------- --- 42,358/50,000  [ 0:00:36 < 0:00:07 , 1,170 it/s ]
#   85% ------------------- --- 42,582/50,000  [ 0:00:36 < 0:00:07 , 1,170 it/s ]
# [Safety Layer] Triggered 11500 times
#   85% ------------------- --- 42,582/50,000  [ 0:00:36 < 0:00:07 , 1,170 it/s ]
# [Safety Layer] Triggered 11600 times
#   85% ------------------- --- 42,582/50,000  [ 0:00:36 < 0:00:07 , 1,170 it/s ]
#   86% ------------------- --- 42,810/50,000  [ 0:00:36 < 0:00:07 , 1,170 it/s ]
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1184         |
# |    iterations           | 21           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0059260568 |
# |    clip_fraction        | 0.031        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.909        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.12         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.0014      |
# |    std                  | 0.977        |
# |    value_loss           | 6.68         |
# ------------------------------------------
#   86% ------------------- --- 42,810/50,000  [ 0:00:36 < 0:00:07 , 1,170 it/s ]
#   86% ------------------- --- 42,810/50,000  [ 0:00:36 < 0:00:07 , 1,170 it/s ]
#   86% ------------------- --- 42,810/50,000  [ 0:00:36 < 0:00:07 , 1,170 it/s ]
#   86% ------------------- --- 42,810/50,000  [ 0:00:36 < 0:00:07 , 1,170 it/s ]
#   86% ------------------- --- 42,810/50,000  [ 0:00:36 < 0:00:07 , 1,170 it/s ]
#   86% ------------------- --- 42,810/50,000  [ 0:00:36 < 0:00:07 , 1,170 it/s ]
#   86% ------------------- --- 42,810/50,000  [ 0:00:36 < 0:00:07 , 1,170 it/s ]
#   86% ------------------- --- 42,810/50,000  [ 0:00:37 < 0:00:07 , 1,170 it/s ]
#   86% ------------------- --- 43,031/50,000  [ 0:00:37 < 0:00:06 , 1,170 it/s ]
# [Safety Layer] Triggered 11700 times
#   86% ------------------- --- 43,031/50,000  [ 0:00:37 < 0:00:06 , 1,170 it/s ]
#   86% ------------------- --- 43,220/50,000  [ 0:00:37 < 0:00:06 , 1,172 it/s ]
# [Safety Layer] Triggered 11800 times
#   86% ------------------- --- 43,220/50,000  [ 0:00:37 < 0:00:06 , 1,172 it/s ]
# [Safety Layer] Triggered 11900 times
#   86% ------------------- --- 43,220/50,000  [ 0:00:37 < 0:00:06 , 1,172 it/s ]
#   87% ------------------- --- 43,418/50,000  [ 0:00:37 < 0:00:06 , 1,175 it/s ]
#   87% -------------------- -- 43,635/50,000  [ 0:00:37 < 0:00:06 , 1,176 it/s ]
#   88% -------------------- -- 43,870/50,000  [ 0:00:37 < 0:00:06 , 1,178 it/s ]
#   88% -------------------- -- 44,103/50,000  [ 0:00:37 < 0:00:06 , 1,177 it/s ]
# [Safety Layer] Triggered 12000 times
#   88% -------------------- -- 44,103/50,000  [ 0:00:37 < 0:00:06 , 1,177 it/s ]
# [Safety Layer] Triggered 12100 times
#   88% -------------------- -- 44,103/50,000  [ 0:00:37 < 0:00:06 , 1,177 it/s ]
#   89% -------------------- -- 44,332/50,000  [ 0:00:37 < 0:00:05 , 1,178 it/s ]
# [Safety Layer] Triggered 12200 times
#   89% -------------------- -- 44,332/50,000  [ 0:00:37 < 0:00:05 , 1,178 it/s ]
#   89% -------------------- -- 44,557/50,000  [ 0:00:37 < 0:00:05 , 1,178 it/s ]
#   90% -------------------- -- 44,792/50,000  [ 0:00:37 < 0:00:05 , 1,178 it/s ]
# Step  45000 | Episodes:   90 | Avg Reward (last 10): 51.77
#   90% -------------------- -- 44,792/50,000  [ 0:00:37 < 0:00:05 , 1,178 it/s ]
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1183         |
# |    iterations           | 22           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0020282213 |
# |    clip_fraction        | 0.0281       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.913        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.79         |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00076     |
# |    std                  | 0.968        |
# |    value_loss           | 6.99         |
# ------------------------------------------
#   90% -------------------- -- 44,792/50,000  [ 0:00:37 < 0:00:05 , 1,178 it/s ]
#   90% -------------------- -- 45,018/50,000  [ 0:00:38 < 0:00:05 , 1,178 it/s ]
#   90% -------------------- -- 45,018/50,000  [ 0:00:38 < 0:00:05 , 1,178 it/s ]
#   90% -------------------- -- 45,018/50,000  [ 0:00:38 < 0:00:05 , 1,178 it/s ]
#   90% -------------------- -- 45,018/50,000  [ 0:00:38 < 0:00:05 , 1,178 it/s ]
#   90% -------------------- -- 45,018/50,000  [ 0:00:38 < 0:00:05 , 1,178 it/s ]
#   90% -------------------- -- 45,018/50,000  [ 0:00:38 < 0:00:05 , 1,178 it/s ]
#   90% -------------------- -- 45,018/50,000  [ 0:00:38 < 0:00:05 , 1,178 it/s ]
#   90% -------------------- -- 45,018/50,000  [ 0:00:38 < 0:00:05 , 1,178 it/s ]
#   90% -------------------- -- 45,018/50,000  [ 0:00:38 < 0:00:05 , 1,178 it/s ]
#   90% -------------------- -- 45,242/50,000  [ 0:00:39 < 0:00:05 , 1,173 it/s ]
#   91% -------------------- -- 45,441/50,000  [ 0:00:39 < 0:00:04 , 1,175 it/s ]
# [Safety Layer] Triggered 12300 times
#   91% -------------------- -- 45,441/50,000  [ 0:00:39 < 0:00:04 , 1,175 it/s ]
#   92% --------------------- - 45,897/50,000  [ 0:00:39 < 0:00:04 , 1,180 it/s ]
# [Safety Layer] Triggered 12400 times
#   92% --------------------- - 45,897/50,000  [ 0:00:39 < 0:00:04 , 1,180 it/s ]
#   92% --------------------- - 46,112/50,000  [ 0:00:39 < 0:00:04 , 1,180 it/s ]
# [Safety Layer] Triggered 12500 times
#   92% --------------------- - 46,112/50,000  [ 0:00:39 < 0:00:04 , 1,180 it/s ]
# [Safety Layer] Triggered 12600 times
#   92% --------------------- - 46,112/50,000  [ 0:00:39 < 0:00:04 , 1,180 it/s ]
#   93% --------------------- - 46,342/50,000  [ 0:00:39 < 0:00:04 , 1,180 it/s ]
# [Safety Layer] Triggered 12700 times
#   93% --------------------- - 46,342/50,000  [ 0:00:39 < 0:00:04 , 1,180 it/s ]
#   93% --------------------- - 46,567/50,000  [ 0:00:39 < 0:00:03 , 1,180 it/s ]
#   94% --------------------- - 46,801/50,000  [ 0:00:39 < 0:00:03 , 1,181 it/s ]
# [Safety Layer] Triggered 12800 times
#   94% --------------------- - 46,801/50,000  [ 0:00:39 < 0:00:03 , 1,181 it/s ]
#   94% --------------------- - 47,027/50,000  [ 0:00:39 < 0:00:03 , 1,181 it/s ]
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1183         |
# |    iterations           | 23           |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0028844578 |
# |    clip_fraction        | 0.0138       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.925        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.301        |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.000246    |
# |    std                  | 0.948        |
# |    value_loss           | 5.29         |
# ------------------------------------------
#   94% --------------------- - 47,027/50,000  [ 0:00:39 < 0:00:03 , 1,181 it/s ]
#   94% --------------------- - 47,027/50,000  [ 0:00:39 < 0:00:03 , 1,181 it/s ]
#   94% --------------------- - 47,027/50,000  [ 0:00:40 < 0:00:03 , 1,181 it/s ]
#   94% --------------------- - 47,027/50,000  [ 0:00:40 < 0:00:03 , 1,181 it/s ]
#   94% --------------------- - 47,027/50,000  [ 0:00:40 < 0:00:03 , 1,181 it/s ]
#   94% --------------------- - 47,027/50,000  [ 0:00:40 < 0:00:03 , 1,181 it/s ]
#   94% --------------------- - 47,027/50,000  [ 0:00:40 < 0:00:03 , 1,181 it/s ]
#   94% --------------------- - 47,027/50,000  [ 0:00:40 < 0:00:03 , 1,181 it/s ]
#   94% --------------------- - 47,249/50,000  [ 0:00:40 < 0:00:03 , 1,179 it/s ]
# [Safety Layer] Triggered 12900 times
#   94% --------------------- - 47,249/50,000  [ 0:00:40 < 0:00:03 , 1,179 it/s ]
# [Safety Layer] Triggered 13000 times
#   94% --------------------- - 47,249/50,000  [ 0:00:40 < 0:00:03 , 1,179 it/s ]
#   95% --------------------- - 47,451/50,000  [ 0:00:40 < 0:00:03 , 1,181 it/s ]
#   95% --------------------- - 47,666/50,000  [ 0:00:40 < 0:00:02 , 1,184 it/s ]
#   96% ----------------------  47,899/50,000  [ 0:00:40 < 0:00:02 , 1,188 it/s ]
#   96% ----------------------  48,122/50,000  [ 0:00:41 < 0:00:02 , 1,189 it/s ]
# [Safety Layer] Triggered 13100 times
#   96% ----------------------  48,122/50,000  [ 0:00:41 < 0:00:02 , 1,189 it/s ]
# [Safety Layer] Triggered 13200 times
#   96% ----------------------  48,122/50,000  [ 0:00:41 < 0:00:02 , 1,189 it/s ]
#   97% ----------------------  48,348/50,000  [ 0:00:41 < 0:00:02 , 1,190 it/s ]
#   97% ----------------------  48,568/50,000  [ 0:00:41 < 0:00:02 , 1,189 it/s ]
# [Safety Layer] Triggered 13300 times
#   97% ----------------------  48,568/50,000  [ 0:00:41 < 0:00:02 , 1,189 it/s ]
# [Safety Layer] Triggered 13400 times
#   97% ----------------------  48,568/50,000  [ 0:00:41 < 0:00:02 , 1,189 it/s ]
#   98% ----------------------  48,801/50,000  [ 0:00:41 < 0:00:02 , 1,189 it/s ]
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1184         |
# |    iterations           | 24           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0032842332 |
# |    clip_fraction        | 0.0504       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.914        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.81         |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00122     |
# |    std                  | 0.946        |
# |    value_loss           | 7.11         |
# ------------------------------------------
#   98% ----------------------  48,801/50,000  [ 0:00:41 < 0:00:02 , 1,189 it/s ]
#   98% ----------------------  49,022/50,000  [ 0:00:41 < 0:00:01 , 1,189 it/s ]
#   98% ----------------------  49,022/50,000  [ 0:00:41 < 0:00:01 , 1,189 it/s ]
#   98% ----------------------  49,022/50,000  [ 0:00:41 < 0:00:01 , 1,189 it/s ]
#   98% ----------------------  49,022/50,000  [ 0:00:41 < 0:00:01 , 1,189 it/s ]
#   98% ----------------------  49,022/50,000  [ 0:00:41 < 0:00:01 , 1,189 it/s ]
#   98% ----------------------  49,022/50,000  [ 0:00:42 < 0:00:01 , 1,189 it/s ]
#   98% ----------------------  49,022/50,000  [ 0:00:42 < 0:00:01 , 1,189 it/s ]
#   98% ----------------------  49,022/50,000  [ 0:00:42 < 0:00:01 , 1,189 it/s ]
#   98% ----------------------  49,242/50,000  [ 0:00:42 < 0:00:01 , 1,179 it/s ]
#   99% ----------------------  49,451/50,000  [ 0:00:42 < 0:00:01 , 1,183 it/s ]
#   99% ----------------------  49,662/50,000  [ 0:00:42 < 0:00:01 , 1,185 it/s ]
# Step  50000 | Episodes:  100 | Avg Reward (last 10): 65.93
#   99% ----------------------  49,662/50,000  [ 0:00:42 < 0:00:01 , 1,185 it/s ]
#  100% ----------------------  49,896/50,000  [ 0:00:42 < 0:00:01 , 1,190 it/s ]
#  100% ----------------------- 50,125/50,000  [ 0:00:42 < 0:00:00 , 1,193 it/s ]
# [Safety Layer] Triggered 13500 times
#  100% ----------------------- 50,125/50,000  [ 0:00:42 < 0:00:00 , 1,193 it/s ]
#  100% ----------------------- 50,361/50,000  [ 0:00:42 < 0:00:00 , 1,197 it/s ]
# [Safety Layer] Triggered 13600 times
#  100% ----------------------- 50,361/50,000  [ 0:00:42 < 0:00:00 , 1,197 it/s ]
#  100% ----------------------- 50,589/50,000  [ 0:00:42 < 0:00:00 , 1,198 it/s ]
# [Safety Layer] Triggered 13700 times
#  100% ----------------------- 50,589/50,000  [ 0:00:42 < 0:00:00 , 1,198 it/s ]
# [Safety Layer] Triggered 13800 times
#  100% ----------------------- 50,589/50,000  [ 0:00:42 < 0:00:00 , 1,198 it/s ]
#  100% ----------------------- 50,809/50,000  [ 0:00:42 < 0:00:00 , 1,198 it/s ]
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1185         |
# |    iterations           | 25           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0009640453 |
# |    clip_fraction        | 0.0335       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.912        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.39         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | 0.000179     |
# |    std                  | 0.942        |
# |    value_loss           | 6.73         |
# ------------------------------------------
#  100% ----------------------- 50,809/50,000  [ 0:00:42 < 0:00:00 , 1,198 it/s ]
#  100% ----------------------- 51,035/50,000  [ 0:00:42 < 0:00:00 , 1,199 it/s ]
#  100% ----------------------- 51,035/50,000  [ 0:00:42 < 0:00:00 , 1,199 it/s ]
#  100% ----------------------- 51,035/50,000  [ 0:00:42 < 0:00:00 , 1,199 it/s ]
#  100% ----------------------- 51,035/50,000  [ 0:00:42 < 0:00:00 , 1,199 it/s ]
#  100% ----------------------- 51,035/50,000  [ 0:00:42 < 0:00:00 , 1,199 it/s ]
#  100% ----------------------- 51,035/50,000  [ 0:00:42 < 0:00:00 , 1,199 it/s ]
#  100% ----------------------- 51,035/50,000  [ 0:00:42 < 0:00:00 , 1,199 it/s ]
#  100% ----------------------- 51,035/50,000  [ 0:00:42 < 0:00:00 , 1,199 it/s ]
#
#  100% ----------------------- 51,035/50,000  [ 0:00:42 < 0:00:00 , 1,199 it/s ]
# [Safety Layer Summary] Total triggers: 13830
#  100% ----------------------- 51,035/50,000  [ 0:00:42 < 0:00:00 , 1,199 it/s ]
#  100% ----------------------- 51,200/50,000  [ 0:00:42 < 0:00:00 , 1,180 it/s ]
#
# [Training Complete]
#
# ============================================================
# Evaluation
# ============================================================
#   Episodes: 10
#   Avg Reward: 63.21
#   Avg Min K-ICS: 341.0%
# [SUCCESS] Agent maintained K-ICS > 100% on average!
# Figure(1400x500)
# [Saved] ppo_training_result.png
#
# [Saved] Model saved to models/ppo_kics

# %%
# !python proof_risk_paradox.py
# Out:
# ============================================================
# Phase 5.1: Risk Paradox Proof
# ============================================================
#
# [Correlation: -0.6]
#   Optimal Hedge Ratio: 0.0%
#   SCR at Optimal: 0.2971
#   SCR at 100% Hedge: 0.3609
#   Capital Savings: 17.69%
#   Paradox Proven: YES ✓
#
# [Correlation: -0.4]
#   Optimal Hedge Ratio: 32.0%
#   SCR at Optimal: 0.3347
#   SCR at 100% Hedge: 0.3609
#   Capital Savings: 7.26%
#   Paradox Proven: YES ✓
#
# [Correlation: -0.2]
#   Optimal Hedge Ratio: 67.0%
#   SCR at Optimal: 0.3550
#   SCR at 100% Hedge: 0.3609
#   Capital Savings: 1.63%
#   Paradox Proven: YES ✓
#
# [Correlation: 0.0]
#   Optimal Hedge Ratio: 100.0%
#   SCR at Optimal: 0.3609
#   SCR at 100% Hedge: 0.3609
#   Capital Savings: 0.00%
#   Paradox Proven: NO
#
# [Correlation: 0.2]
#   Optimal Hedge Ratio: 100.0%
#   SCR at Optimal: 0.3609
#   SCR at 100% Hedge: 0.3609
#   Capital Savings: 0.00%
#   Paradox Proven: NO
#
# ============================================================
# [SUCCESS] Risk Paradox Proven!
#   3/5 scenarios show the paradox
# Figure(1200x600)
#
# [Saved] risk_paradox_proof.png

# %%
# !python solvency_visualizer.py
# Out:
# ============================================================
# Phase 5.2: Solvency Analysis (COVID-19 Scenario)
# ============================================================
#
# [100% Hedge]
#   Min K-ICS: 401.7%
#   Final K-ICS: 401.7%
#
# [80% Fixed]
#   Min K-ICS: 317.7%
#   Final K-ICS: 323.8%
#
# [Dynamic Shield]
#   Min K-ICS: 391.2%
#   Final K-ICS: 403.7%
# Figure(1400x1200)
#
# [Saved] kics_defense_result.png

# %%
# !python stress_safety.py
# Out:
# ============================================================
# Phase 5.3: Safety Layer Stress Test
# ============================================================
#
# [Test 1] VIX > 40 Injection Test
# ----------------------------------------
# Step  1 | VIX: 15 | Hedge: 0.60 | Action: 3 | CRITICAL: K-ICS < 100%, FORCE HEDGE 100%
# Step  2 | VIX: 20 | Hedge: 0.70 | Action: 3 | CRITICAL: K-ICS < 100%, FORCE HEDGE 100%
# Step  3 | VIX: 25 | Hedge: 0.80 | Action: 3 | CRITICAL: K-ICS < 100%, FORCE HEDGE 100%
# Step  4 | VIX: 30 | Hedge: 0.90 | Action: 3 | CRITICAL: K-ICS < 100%, FORCE HEDGE 100%
# Step  5 | VIX: 35 | Hedge: 1.00 | Action: 3 | CRITICAL: K-ICS < 100%, FORCE HEDGE 100%
# Step  6 | VIX: 40 | Hedge: 1.00 | Action: 3 | CRITICAL: K-ICS < 100%, FORCE HEDGE 100%
#   >>> Emergency: Gradual De-risking Triggered <<<
# Step  7 | VIX: 45 | Hedge: 1.00 | Action: 3 | CRITICAL: K-ICS < 100%, FORCE HEDGE 100%
#   >>> Emergency: Gradual De-risking Triggered <<<
# Step  8 | VIX: 50 | Hedge: 1.00 | Action: 3 | CRITICAL: K-ICS < 100%, FORCE HEDGE 100%
#   >>> Emergency: Gradual De-risking Triggered <<<
# Step  9 | VIX: 55 | Hedge: 1.00 | Action: 3 | CRITICAL: K-ICS < 100%, FORCE HEDGE 100%
#   >>> Emergency: Gradual De-risking Triggered <<<
# Step 10 | VIX: 50 | Hedge: 1.00 | Action: 3 | CRITICAL: K-ICS < 100%, FORCE HEDGE 100%
#   >>> Emergency: Gradual De-risking Triggered <<<
# Step 11 | VIX: 45 | Hedge: 1.00 | Action: 3 | CRITICAL: K-ICS < 100%, FORCE HEDGE 100%
#   >>> Emergency: Gradual De-risking Triggered <<<
# Step 12 | VIX: 40 | Hedge: 1.00 | Action: 3 | CRITICAL: K-ICS < 100%, FORCE HEDGE 100%
#   >>> Emergency: Gradual De-risking Triggered <<<
# Step 13 | VIX: 35 | Hedge: 1.00 | Action: 3 | CRITICAL: K-ICS < 100%, FORCE HEDGE 100%
# Step 14 | VIX: 30 | Hedge: 1.00 | Action: 3 | CRITICAL: K-ICS < 100%, FORCE HEDGE 100%
# Step 15 | VIX: 25 | Hedge: 1.00 | Action: 3 | CRITICAL: K-ICS < 100%, FORCE HEDGE 100%
# Step 16 | VIX: 20 | Hedge: 1.00 | Action: 3 | CRITICAL: K-ICS < 100%, FORCE HEDGE 100%
#
# [Test 2] Gradual Increase Verification
# ----------------------------------------
# Max single-step hedge change: 0.10
# [PASS] Hedge ratio changed gradually (max step <= 0.15)
#
# [Test 3] K-ICS < 100% Penalty Test
# ----------------------------------------
# Forced K-ICS Ratio: 3.0%
# Agent Response: CRITICAL: K-ICS < 100%, FORCE HEDGE 100%
# [PASS] Agent correctly responded to K-ICS < 100% with maximum hedge increase
#
# ============================================================
# Stress Test Results
# ============================================================
# ✓ Emergency De-risking: TRIGGERED
# ✓ Gradual Increase: CONFIRMED
#
# [SUCCESS] Safety Layer passed all stress tests!

# %%
# !python backtest.py
# Out:
# ============================================================
# Phase 4: Backtesting & Performance Analysis
# ============================================================
#
# [Scenario: NORMAL]
#
# [Scenario: 2008_CRISIS]
#
# [Scenario: 2020_PANDEMIC]
#
# [Scenario: STAGFLATION]
#
# [Scenario: CORRELATION_BREAKDOWN]
#
# ============================================================
# Performance Summary (All Scenarios)
# ============================================================
#                   CAGR    Sharpe     MDD     RCR  Avg_SCR  Net_Benefit
# Strategy
# 100% Hedge     -0.3976    0.0000 -0.6334 -0.0009   0.3609    -100.0902
# 80% Fixed      -0.3151 -542.4425 -0.5274  0.0124   0.3501     -79.0075
# Dynamic Shield -0.1615  -59.7059 -0.2942  0.0472   0.3387     -43.4814
# Rule-based     -0.1963  -93.7432 -0.3512  0.0375   0.3401     -51.3204
#
# [Winner by Metric]
#   Best CAGR:   Dynamic Shield (-0.1615)
#   Best Sharpe: 100% Hedge (0.0000)
#   Best MDD:    Dynamic Shield (-0.2942)
#   Best RCR:    Dynamic Shield (0.0472)
# Figure(1400x1000)

# %%
# !python advanced_viz.py
# Out:
# ============================================================
# Phase 5.5: Advanced Visualization (XAI)
# ============================================================
#
# [Plot 1] Counterfactual Dashboard (Decision Boundary)
# --------------------------------------------------
# Figure(1200x600)
# [Saved] counterfactual_dashboard.png
#
# [Plot 2] Efficient Frontier (Risk vs Cost)
# --------------------------------------------------
# Figure(1000x800)
# [Saved] efficient_frontier.png
#
# [Efficient Frontier Summary]
#   100% Hedge     : Risk=36.09%, Cost=60.00%
#   80% Fixed      : Risk=34.95%, Cost=48.00%
#   Rule-based     : Risk=33.97%, Cost=31.44%
#   Dynamic Shield : Risk=33.84%, Cost=26.23%
#
# [SUCCESS] Dynamic Shield is in the SWEET SPOT!
#   → Lower risk AND lower cost than 100% Hedge!
#
# ============================================================
# [COMPLETE] All advanced visualizations generated!
#   1. counterfactual_dashboard.png
#   2. efficient_frontier.png
# ============================================================

# %%
# !python shap_analysis.py
# Out:
# [WARNING] SHAP not installed. Run: pip install shap
# ============================================================
# Phase 6.2.1: SHAP - Why Not 100% Hedge?
# ============================================================
#
# [Feature Importance Analysis]
# --------------------------------------------------
#
# Normal (Natural Hedge):
#   Correlation: [-0.6, -0.2)
#   Optimal Hedge Ratio: 1.7%
#   Average SCR: 0.3405
#
# Transition:
#   Correlation: [-0.2, 0.5)
#   Optimal Hedge Ratio: 0.5%
#   Average SCR: 0.3912
#
# Panic:
#   Correlation: [0.5, 0.9)
#   Optimal Hedge Ratio: 1.4%
#   Average SCR: 0.4333
#
# ============================================================
# WHY NOT 100% HEDGE?
# ============================================================
#
# [Normal Regime: Correlation = -0.4]
#   100% Hedge: SCR=0.3609, Annual Cost=50.40%
#    80% Hedge: SCR=0.3479, Annual Cost=40.32%
#   SCR Difference: 1.30%p (80% is BETTER)
#   Cost Savings: 10.08%p
#
# [CONCLUSION]
#   1. Natural Hedge 효과: 주식-환율 음의 상관관계로 분산 효과
#   2. 헤지 비용 절감: 불필요한 오버헤지 비용 제거
#   3. Risk Paradox: 적정 헤지가 완전 헤지보다 위험이 낮음
# Figure(1400x1000)
#
# [Saved] shap_why_not_analysis.png

# %%
# !python phase6_final_review.py
# Out:
# ======================================================================
# FINAL REVIEW SUMMARY
# ======================================================================
# ======================================================================
# Phase 6.1: Logic Consistency Check
# ======================================================================
#
# [Check 1] Risk Paradox Proof
# --------------------------------------------------
#   SCR at 80% Hedge: 0.3479
#   SCR at 100% Hedge: 0.3609
#   [PASS] 80% 헤지가 100% 헤지보다 낮은 총 위험액!
#
# [Check 2] Safety Layer Operation
# --------------------------------------------------
#   VIX=45 상황에서 에이전트 반응: CRITICAL: K-ICS < 100%, FORCE HEDGE 100%
#   [PASS] Emergency De-risking Triggered!
#
# [Check 3] Surrogate Model Accuracy
# --------------------------------------------------
# === Phase 2-2: Training AI Surrogate Model ===
# [-] Training MLP...
#
# [-] Validating Scalability...
# [-] Scalability Test (Asset: 10B KRW): MAPE = 0.0469%
# [SUCCESS] AI Brain is Robust & Scalable!
# Figure(800x600)
#   Real SCR: 0.4362
#   Pred SCR: 0.4362
#   Error Rate: 0.00%
#   [PASS] Surrogate 오차율 5% 미만!
#
# ======================================================================
# Phase 6.2: Award-Winning Action Items
# ======================================================================
#
# [Item 1] 'Why Not' Analysis (SHAP)
# --------------------------------------------------
#   [PENDING] 시각화 파일 생성 필요
#            Run: python src/validation/shap_analysis.py
#
# [Item 2] Efficient Frontier
# --------------------------------------------------
#   [PENDING] 시각화 파일 생성 필요
#
# [Item 3] RCR (Risk-Cost Ratio) Metric
# --------------------------------------------------
#   [PASS] RCR 계산 로직 구현 완료
#
# [Item 4] Code Philosophy Annotation
# --------------------------------------------------
#   [PASS] 'Capital Optimization, not Prediction' 철학 명시됨
#
# ======================================================================
# OVERALL STATUS
# ======================================================================
#
# [Logic Consistency]
#   ✅ risk_paradox
#   ✅ safety_layer
#   ✅ surrogate_error
#
# [Award-Winning Items]
#   ⏳ why_not_analysis
#   ⏳ efficient_frontier
#   ✅ rcr_metric
#   ✅ code_philosophy
#
# [ACTION REQUIRED]
#   - Award-Winning 항목 완성 필요
